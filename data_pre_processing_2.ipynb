# %% [markdown]
# # **Pre-processing of the bioactivity data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Load dataset
import pandas as pd
file1 = "/content/drive/MyDrive/bioactivity/beta_secretase1_bioactivity_data.csv"
df = pd.read_csv(file1)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN        78857                  []
# 1         NaN              NaN       391560                  []
# 2         NaN              NaN       391983                  []
# 3         NaN              NaN       395858                  []
# 4         NaN              NaN       395859                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL653511  Inhibitory activity against Beta-secretase 1 w...
# 1    CHEMBL653332  Compound was tested for its inhibitory activit...
# 2    CHEMBL653512               Inhibition of human Beta-secretase 1
# 3    CHEMBL653512               Inhibition of human Beta-secretase 1
# 4    CHEMBL653512               Inhibition of human Beta-secretase 1
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# 1          B                      NaN                     NaN  BAO_0000190
# 2          B                      NaN                     NaN  BAO_0000190
# 3          B                      NaN                     NaN  BAO_0000190
# 4          B                      NaN                     NaN  BAO_0000190
#
#    ... target_organism  target_pref_name target_tax_id text_value toid  type  \
# 0  ...    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 1  ...    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 2  ...    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 3  ...    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 4  ...    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
#
#   units    uo_units upper_value    value
# 0    nM  UO_0000065         NaN  413.000
# 1    uM  UO_0000065         NaN    0.002
# 2    uM  UO_0000065         NaN    0.460
# 3    uM  UO_0000065         NaN    9.000
# 4    uM  UO_0000065         NaN    5.600
#
# [5 rows x 46 columns]

# %% [markdown]
# # **Handling missing data**

# %% [markdown]
# If any compounds has missing value for the standard_value column then drop it

# %%
#Count how many compounds have missing values in the 'standard_value' column
missing_values_count = df['standard_value'].isna().sum()
print(f"Number of compounds with missing standard_value: {missing_values_count}")
# Out:
# Number of compounds with missing standard_value: 148

# %%
# drop compounds compounds that has missing values for the standard_value column
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                              action_type activity_comment  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 10717  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10718  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10719  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10720  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 10721  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#        activity_id activity_properties assay_chembl_id  \
# 0            78857                  []    CHEMBL653511
# 1           391560                  []    CHEMBL653332
# 2           391983                  []    CHEMBL653512
# 3           395858                  []    CHEMBL653512
# 4           395859                  []    CHEMBL653512
# ...            ...                 ...             ...
# 10717     25076257                  []   CHEMBL5254629
# 10718     25076258                  []   CHEMBL5254629
# 10719     25076259                  []   CHEMBL5254629
# 10720     25076260                  []   CHEMBL5254629
# 10721     25076261                  []   CHEMBL5254629
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity against Beta-secretase 1 w...          B
# 1      Compound was tested for its inhibitory activit...          B
# 2                   Inhibition of human Beta-secretase 1          B
# 3                   Inhibition of human Beta-secretase 1          B
# 4                   Inhibition of human Beta-secretase 1          B
# ...                                                  ...        ...
# 10717                         Inhibition of human BACE-1          B
# 10718                         Inhibition of human BACE-1          B
# 10719                         Inhibition of human BACE-1          B
# 10720                         Inhibition of human BACE-1          B
# 10721                         Inhibition of human BACE-1          B
#
#        assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 0                          NaN                     NaN  BAO_0000190  ...
# 1                          NaN                     NaN  BAO_0000190  ...
# 2                          NaN                     NaN  BAO_0000190  ...
# 3                          NaN                     NaN  BAO_0000190  ...
# 4                          NaN                     NaN  BAO_0000190  ...
# ...                        ...                     ...          ...  ...
# 10717                      NaN                     NaN  BAO_0000190  ...
# 10718                      NaN                     NaN  BAO_0000190  ...
# 10719                      NaN                     NaN  BAO_0000190  ...
# 10720                      NaN                     NaN  BAO_0000190  ...
# 10721                      NaN                     NaN  BAO_0000190  ...
#
#       target_organism  target_pref_name target_tax_id text_value toid  type  \
# 0        Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 1        Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 2        Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 3        Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 4        Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# ...               ...               ...           ...        ...  ...   ...
# 10717    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 10718    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 10719    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 10720    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
# 10721    Homo sapiens  Beta-secretase 1          9606        NaN  NaN  IC50
#
#       units    uo_units upper_value    value
# 0        nM  UO_0000065         NaN  413.000
# 1        uM  UO_0000065         NaN    0.002
# 2        uM  UO_0000065         NaN    0.460
# 3        uM  UO_0000065         NaN    9.000
# 4        uM  UO_0000065         NaN    5.600
# ...     ...         ...         ...      ...
# 10717    uM  UO_0000065         NaN    2.800
# 10718    uM  UO_0000065         NaN    1.600
# 10719    uM  UO_0000065         NaN    4.500
# 10720    uM  UO_0000065         NaN    2.400
# 10721    uM  UO_0000065         NaN    2.100
#
# [10574 rows x 46 columns]

# %% [markdown]
# # **Labeling compounds as either being active, inactive or intermediate**

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values of less than 100 nM will be considered to be active while those greater than 1000 nM will be considered to be inactive. As for those values in between 1,00 and 1000 nM will be referred to as intermediate.

# %%
## classify molecules based on bioactivity and assign the activity class into a list
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 1000:
    bioactivity_class.append("inactive")
  elif float(i) <= 100:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
# Count the occurrences of each class

from collections import Counter

class_counts = Counter(bioactivity_class)

# Print the number of compounds in each class
print(f"Number of active compounds: {class_counts['active']}")
print(f"Number of inactive compounds: {class_counts['inactive']}")
print(f"Number of intermediate compounds: {class_counts['intermediate']}")
# Out:
# Number of active compounds: 4477
# Number of inactive compounds: 3599
# Number of intermediate compounds: 2498

# %% [markdown]
# **Assign the molecule_chembl_id to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# **Assign canonical_smiles to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# **Assign IC50(nM) to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL406146  CC(C)C[C@H](NC(=O)[C@@H](NC(=O)[C@@H](N)CCC(=O...
# 1        CHEMBL78946  CC(C)C[C@H](NC(=O)[C@H](CC(N)=O)NC(=O)[C@@H](N...
# 2       CHEMBL324109  CCC(C)C[C@H](NC(=O)[C@H](CC(C)C)NC(C)=O)[C@@H]...
# 3       CHEMBL114147  CC(=O)NCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)CC(=O)...
# 4       CHEMBL419949  CC(=O)N[C@@H](Cc1ccccc1)C(=O)N[C@@H](Cc1ccccc1...
#
#   bioactivity_class  standard_value
# 0      intermediate           413.0
# 1            active             2.0
# 2      intermediate           460.0
# 3          inactive          9000.0
# 4          inactive          5600.0

# %%
df3.to_csv('beta_secretase1_bioactivity_preprocessed_data.csv', index=False)

# %%
! cp beta_secretase1_bioactivity_preprocessed_data.csv "/content/drive/MyDrive/bioactivity/"

# %%
#! ls "/content/drive/MyDrive/bioactivity/"
